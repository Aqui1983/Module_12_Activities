# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import style
style.use("ggplot")
# from matplotlib import rcParams
# rcParams['figure.figsize'] = 10, 8

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=40, centers=2, random_state=42, cluster_std=1.25)
plt.scatter(X[:, 0], X[:, 1], c=y, s=100, cmap="bwr");
plt.show()

# %%
from sklearn.svm import SVC

model = SVC(kernel='linear')
model.fit(X,y)
# Out:
# SVC(kernel='linear')

# %%
x_min= X[:,0].min()
x_max= X[:,0].max()
y_min= X[:,1].min()
y_max= X[:,1].max()

print(x_min,x_max,y_min,y_max)
# Out:
# -4.665344913694041 6.487246392154996 -0.5112914593103839 11.329633858834494

# %%
XX,YY = np.mgrid[x_min:x_max,y_min:y_max]
print(XX)
# Out:
# [[-4.66534491 -4.66534491 -4.66534491 -4.66534491 -4.66534491 -4.66534491
#   -4.66534491 -4.66534491 -4.66534491 -4.66534491 -4.66534491 -4.66534491]
#  [-3.66534491 -3.66534491 -3.66534491 -3.66534491 -3.66534491 -3.66534491
#   -3.66534491 -3.66534491 -3.66534491 -3.66534491 -3.66534491 -3.66534491]
#  [-2.66534491 -2.66534491 -2.66534491 -2.66534491 -2.66534491 -2.66534491
#   -2.66534491 -2.66534491 -2.66534491 -2.66534491 -2.66534491 -2.66534491]
#  [-1.66534491 -1.66534491 -1.66534491 -1.66534491 -1.66534491 -1.66534491
#   -1.66534491 -1.66534491 -1.66534491 -1.66534491 -1.66534491 -1.66534491]
#  [-0.66534491 -0.66534491 -0.66534491 -0.66534491 -0.66534491 -0.66534491
#   -0.66534491 -0.66534491 -0.66534491 -0.66534491 -0.66534491 -0.66534491]
#  [ 0.33465509  0.33465509  0.33465509  0.33465509  0.33465509  0.33465509
#    0.33465509  0.33465509  0.33465509  0.33465509  0.33465509  0.33465509]
#  [ 1.33465509  1.33465509  1.33465509  1.33465509  1.33465509  1.33465509
#    1.33465509  1.33465509  1.33465509  1.33465509  1.33465509  1.33465509]
#  [ 2.33465509  2.33465509  2.33465509  2.33465509  2.33465509  2.33465509
#    2.33465509  2.33465509  2.33465509  2.33465509  2.33465509  2.33465509]
#  [ 3.33465509  3.33465509  3.33465509  3.33465509  3.33465509  3.33465509
#    3.33465509  3.33465509  3.33465509  3.33465509  3.33465509  3.33465509]
#  [ 4.33465509  4.33465509  4.33465509  4.33465509  4.33465509  4.33465509
#    4.33465509  4.33465509  4.33465509  4.33465509  4.33465509  4.33465509]
#  [ 5.33465509  5.33465509  5.33465509  5.33465509  5.33465509  5.33465509
#    5.33465509  5.33465509  5.33465509  5.33465509  5.33465509  5.33465509]
#  [ 6.33465509  6.33465509  6.33465509  6.33465509  6.33465509  6.33465509
#    6.33465509  6.33465509  6.33465509  6.33465509  6.33465509  6.33465509]]

# %%
Z = model.decision_function(np.c_[XX.ravel(),YY.ravel()])
print(Z)
# Out:
# [ 2.79983696e-01  3.25552530e-03 -2.73472645e-01 -5.50200816e-01
#  -8.26928987e-01 -1.10365716e+00 -1.38038533e+00 -1.65711350e+00
#  -1.93384167e+00 -2.21056984e+00 -2.48729801e+00 -2.76402618e+00
#   5.60529135e-01  2.83800965e-01  7.07279384e-03 -2.69655377e-01
#  -5.46383548e-01 -8.23111719e-01 -1.09983989e+00 -1.37656806e+00
#  -1.65329623e+00 -1.93002440e+00 -2.20675257e+00 -2.48348074e+00
#   8.41074575e-01  5.64346404e-01  2.87618233e-01  1.08900624e-02
#  -2.65838108e-01 -5.42566279e-01 -8.19294450e-01 -1.09602262e+00
#  -1.37275079e+00 -1.64947896e+00 -1.92620713e+00 -2.20293530e+00
#   1.12162001e+00  8.44891843e-01  5.68163673e-01  2.91435502e-01
#   1.47073309e-02 -2.62020840e-01 -5.38749011e-01 -8.15477181e-01
#  -1.09220535e+00 -1.36893352e+00 -1.64566169e+00 -1.92238986e+00
#   1.40216545e+00  1.12543728e+00  8.48709112e-01  5.71980941e-01
#   2.95252770e-01  1.85245994e-02 -2.58203571e-01 -5.34931742e-01
#  -8.11659913e-01 -1.08838808e+00 -1.36511625e+00 -1.64184443e+00
#   1.68271089e+00  1.40598272e+00  1.12925455e+00  8.52526380e-01
#   5.75798210e-01  2.99070039e-01  2.23418680e-02 -2.54386303e-01
#  -5.31114474e-01 -8.07842644e-01 -1.08457082e+00 -1.36129899e+00
#   1.96325633e+00  1.68652816e+00  1.40979999e+00  1.13307182e+00
#   8.56343649e-01  5.79615478e-01  3.02887307e-01  2.61591365e-02
#  -2.50569034e-01 -5.27297205e-01 -8.04025376e-01 -1.08075355e+00
#   2.24380177e+00  1.96707360e+00  1.69034543e+00  1.41361726e+00
#   1.13688909e+00  8.60160917e-01  5.83432747e-01  3.06704576e-01
#   2.99764051e-02 -2.46751766e-01 -5.23479937e-01 -8.00208107e-01
#   2.52434721e+00  2.24761904e+00  1.97089087e+00  1.69416270e+00
#   1.41743453e+00  1.14070636e+00  8.63978186e-01  5.87250015e-01
#   3.10521844e-01  3.37936736e-02 -2.42934497e-01 -5.19662668e-01
#   2.80489265e+00  2.52816448e+00  2.25143631e+00  1.97470814e+00
#   1.69797997e+00  1.42125180e+00  1.14452363e+00  8.67795455e-01
#   5.91067284e-01  3.14339113e-01  3.76109421e-02 -2.39117229e-01
#   3.08543809e+00  2.80870992e+00  2.53198175e+00  2.25525358e+00
#   1.97852541e+00  1.70179724e+00  1.42506906e+00  1.14834089e+00
#   8.71612723e-01  5.94884552e-01  3.18156381e-01  4.14282107e-02
#   3.36598353e+00  3.08925536e+00  2.81252719e+00  2.53579902e+00
#   2.25907085e+00  1.98234267e+00  1.70561450e+00  1.42888633e+00
#   1.15215816e+00  8.75429992e-01  5.98701821e-01  3.21973650e-01]

# %%
Z = Z.reshape(XX.shape)

# %%
plt.contour(XX,YY,Z,linestyles=['--','-','--'], levels=[-.5,0,.5])
plt.scatter(X[:,0], X[:,1], c=y, cmap='bwr')
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)

# %%
model = SVC(kernel='linear')
model.fit(X_train,y_train)
predictions = model.predict(X_test)
predictions
# Out:
# array([1, 1, 1, 0, 0, 0, 1, 0, 1, 0])

# %%
x_min = X[:,0].min()
x_max = X[:,0].max()
y_min = X[:,1].min()
y_max = X[:,1].max()

XX,YY = np.mgrid[x_min:x_max,y_min:y_max]
Z = model.decision_function(np.c_[XX.ravel(),YY.ravel()])
Z = Z.reshape(XX.shape)

plt.contour(XX,YY,Z, colors=['k','k','k'],
            linestyles=['--','-','--'], levels=[-.5,0,.5])
plt.scatter(X[:,0], X[:,1], c=y, cmap='bwr', edgecolors='k', s=100)
plt.show()
